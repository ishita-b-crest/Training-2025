# %%
pip install pinecone
# Out:
# Collecting pinecone
#   Downloading pinecone-7.3.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: certifi>=2019.11.17 in c:\users\ishitabhojani\anaconda3\lib\site-packages (from pinecone) (2025.4.26)
# Collecting pinecone-plugin-assistant<2.0.0,>=1.6.0 (from pinecone)
#   Downloading pinecone_plugin_assistant-1.8.0-py3-none-any.whl.metadata (30 kB)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\ishitabhojani\anaconda3\lib\site-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\ishitabhojani\anaconda3\lib\site-packages (from pinecone) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\ishitabhojani\anaconda3\lib\site-packages (from pinecone) (2.3.0)
# Requirement already satisfied: packaging<25.0,>=24.2 in c:\users\ishitabhojani\anaconda3\lib\site-packages (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (24.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\ishitabhojani\anaconda3\lib\site-packages (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ishitabhojani\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ishitabhojani\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (3.7)
# Requirement already satisfied: six>=1.5 in c:\users\ishitabhojani\anaconda3\lib\site-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Downloading pinecone-7.3.0-py3-none-any.whl (587 kB)
#    ---------------------------------------- 0.0/587.6 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/587.6 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/587.6 kB ? eta -:--:--
#    --------------------------------- ---- 524.3/587.6 kB 967.5 kB/s eta 0:00:01
#    --------------------------------- ---- 524.3/587.6 kB 967.5 kB/s eta 0:00:01
#    -------------------------------------- 587.6/587.6 kB 426.9 kB/s eta 0:00:00
# Downloading pinecone_plugin_assistant-1.8.0-py3-none-any.whl (259 kB)
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Installing collected packages: pinecone-plugin-interface, pinecone-plugin-assistant, pinecone
#
#    ------------- -------------------------- 1/3 [pinecone-plugin-assistant]
#    ------------- -------------------------- 1/3 [pinecone-plugin-assistant]
#    ------------- -------------------------- 1/3 [pinecone-plugin-assistant]
#    ------------- -------------------------- 1/3 [pinecone-plugin-assistant]
#    ------------- -------------------------- 1/3 [pinecone-plugin-assistant]
#    -------------------------- ------------- 2/3 [pinecone]
#    -------------------------- ------------- 2/3 [pinecone]
#    -------------------------- ------------- 2/3 [pinecone]
#    -------------------------- ------------- 2/3 [pinecone]
#    -------------------------- ------------- 2/3 [pinecone]
#    -------------------------- ------------- 2/3 [pinecone]
#    -------------------------- ------------- 2/3 [pinecone]
#    -------------------------- ------------- 2/3 [pinecone]
#    -------------------------- ------------- 2/3 [pinecone]
#    -------------------------- ------------- 2/3 [pinecone]
#    -------------------------- ------------- 2/3 [pinecone]
#    -------------------------- ------------- 2/3 [pinecone]
#    -------------------------- ------------- 2/3 [pinecone]
#    ---------------------------------------- 3/3 [pinecone]
#
# Successfully installed pinecone-7.3.0 pinecone-plugin-assistant-1.8.0 pinecone-plugin-interface-0.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from pinecone import Pinecone, ServerlessSpec

pc = Pinecone(api_key="pcsk_6TmN5V_N5icefTpnjG7j6cMGkg4fmHtGmUDjjbx9xf4dwkrB1vdaZ6aynV7TKvRVLaesx2")

# %%
index_name = "developer-quickstart-py"

if not pc.has_index(index_name):
    pc.create_index_for_model(
        name=index_name,
        cloud="aws",
        region="us-east-1",
        embed={
            "model":"llama-text-embed-v2",
            "field_map":{"text": "chunk_text"}
        }
    )
