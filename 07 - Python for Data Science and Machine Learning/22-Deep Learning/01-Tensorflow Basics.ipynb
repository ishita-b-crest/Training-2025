332.0 MB 2.8 MB/s eta 0:00:29
#    ------------------------------ --------- 253.0/332.0 MB 2.8 MB/s eta 0:00:29
#    ------------------------------ --------- 253.5/332.0 MB 2.8 MB/s eta 0:00:29
#    ------------------------------ --------- 254.0/332.0 MB 2.8 MB/s eta 0:00:29
#    ------------------------------ --------- 254.5/332.0 MB 2.8 MB/s eta 0:00:29
#    ------------------------------ --------- 255.3/332.0 MB 2.8 MB/s eta 0:00:28
#    ------------------------------ --------- 256.4/332.0 MB 2.8 MB/s eta 0:00:28
#    ------------------------------ --------- 256.9/332.0 MB 2.8 MB/s eta 0:00:28
#    ------------------------------- -------- 257.4/332.0 MB 2.8 MB/s eta 0:00:27
#    ------------------------------- -------- 258.2/332.0 MB 2.8 MB/s eta 0:00:27
#    ------------------------------- -------- 258.7/332.0 MB 2.8 MB/s eta 0:00:27
#    ------------------------------- -------- 259.5/332.0 MB 2.8 MB/s eta 0:00:27
#    ------------------------------- -------- 260.3/332.0 MB 2.8 MB/s eta 0:00:26
#    ------------------------------- -------- 260.8/332.0 MB 2.8 MB/s eta 0:00:26
#    ------------------------------- -------- 261.6/332.0 MB 2.8 MB/s eta 0:00:26
#    ------------------------------- -------- 262.4/332.0 MB 2.8 MB/s eta 0:00:26
#    ------------------------------- -------- 263.2/332.0 MB 2.8 MB/s eta 0:00:25
#    ------------------------------- -------- 263.7/332.0 MB 2.8 MB/s eta 0:00:25
#    ------------------------------- -------- 264.5/332.0 MB 2.8 MB/s eta 0:00:25
#    ------------------------------- -------- 265.0/332.0 MB 2.8 MB/s eta 0:00:24
#    ------------------------------- -------- 265.6/332.0 MB 2.8 MB/s eta 0:00:24
#    -------------------------------- ------- 266.1/332.0 MB 2.8 MB/s eta 0:00:24
#    -------------------------------- ------- 266.6/332.0 MB 2.8 MB/s eta 0:00:24
#    -------------------------------- ------- 267.4/332.0 MB 2.8 MB/s eta 0:00:24
#    -------------------------------- ------- 267.9/332.0 MB 2.8 MB/s eta 0:00:24
# ...
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ---------------------------------------- 16/16 [tensorflow]
#
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 flatbuffers-25.2.10 gast-0.6.0 google_pasta-0.2.0 grpcio-1.75.0 keras-3.11.3 libclang-18.1.1 ml_dtypes-0.5.3 namex-0.1.0 opt_einsum-3.4.0 optree-0.17.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.1.0

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.20.0

# %% [markdown]
# ### Simple Constants
#
# Let's show how to create a simple constant with Tensorflow, which TF stores as a tensor object:

# %%
hello = tf.constant('Hello World')

# %%
type(hello)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
x = tf.constant(100)

# %%
type(x)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %% [markdown]
# ### Running Sessions
#
# Now you can create a TensorFlow Session, which is a class for running TensorFlow operations.
#
# A `Session` object encapsulates the environment in which `Operation`
# objects are executed, and `Tensor` objects are evaluated. For example:

# %%
sess = tf.Session()

# %%
sess.run(hello)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sess.run(hello)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:977, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     974 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     976 try:
# --> 977   result = self._run(None, fetches, feed_dict, options_ptr,
#     978                      run_metadata_ptr)
#     979   if run_metadata:
#     980     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:1205, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1202       feed_map[compat.as_bytes(subfeed_t.name)] = (subfeed_t, subfeed_val)
#    1204 # Create a fetch handler to take care of the structure of fetches.
# -> 1205 fetch_handler = _FetchHandler(
#    1206     self._graph, fetches, feed_dict_tensor, feed_handles=feed_handles)
#    1208 # Run request and get response.
#    1209 # We need to keep the returned movers alive for the following _do_run().
#    1210 # These movers are no longer needed when _do_run() completes, and
#    1211 # are deleted when `movers` goes out of scope when this _run() ends.
#    1212 # TODO(yuanbyu, keveman): Revisit whether we should just treat feeding
#    1213 # of a handle from a different device as an error.
#    1214 _ = self._update_with_movers(feed_dict_tensor, feed_map)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:494, in _FetchHandler.__init__(self, graph, fetches, feeds, feed_handles)
#     482 """Creates a fetch handler.
#     483
#     484 Args:
#    (...)
#     491     direct feeds.
#     492 """
#     493 with graph.as_default():
# --> 494   self._fetch_mapper = _FetchMapper.for_fetch(fetches)
#     495 self._fetches = []
#     496 self._targets = []
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:285, in _FetchMapper.for_fetch(fetch)
#     283     if isinstance(fetch, tensor_type):
#     284       fetches, contraction_fn = fetch_fn(fetch)
# --> 285       return _ElementFetchMapper(fetches, contraction_fn)
#     286 # Did not find anything.
#     287 raise TypeError(f'Argument `fetch` = {fetch} has invalid type '
#     288                 f'"{type(fetch).__name__}"')
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:313, in _ElementFetchMapper.__init__(self, fetches, contraction_fn)
#     311 for fetch in fetches:
#     312   try:
# --> 313     self._unique_fetches.append(ops.get_default_graph().as_graph_element(
#     314         fetch, allow_tensor=True, allow_operation=True))
#     315   except TypeError as e:
#     316     raise TypeError(f'Argument `fetch` = {fetch} has invalid type '
#     317                     f'"{type(fetch).__name__}" must be a string or Tensor. '
#     318                     f'({str(e)})')
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:2929, in Graph.as_graph_element(self, obj, allow_tensor, allow_operation)
#    2926   return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#    2928 with self._lock:
# -> 2929   return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:3017, in Graph._as_graph_element_locked(self, obj, allow_tensor, allow_operation)
#    3013     raise ValueError(err_msg)
#    3015 elif isinstance(obj, tensor_lib.Tensor) and allow_tensor:
#    3016   # Actually obj is just the object it's referring to.
# -> 3017   if obj.graph is not self:
#    3018     raise ValueError("Tensor %s is not an element of this graph." % obj)
#    3019   return obj
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\tensor.py:260, in Tensor.__getattr__(self, name)
#     252 if name in {"T", "astype", "ravel", "transpose", "reshape", "clip", "size",
#     253             "tolist", "data"}:
#     254   # TODO(wangpeng): Export the enable_numpy_behavior knob
#     255   raise AttributeError(
#     256       f"{type(self).__name__} object has no attribute '{name}'. " + """
#     257     If you are looking for numpy-related methods, please run the following:
#     258     tf.experimental.numpy.experimental_enable_numpy_behavior()
#     259   """)
# --> 260 self.__getattribute__(name)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:606, in _EagerTensorBase.graph(self)
#     604 @property
#     605 def graph(self) -> NoReturn:
# --> 606   raise AttributeError(
#     607       "Tensor.graph is undefined when eager execution is enabled.")
#
# AttributeError: Tensor.graph is undefined when eager execution is enabled.

# %%
type(sess.run(hello))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 type(sess.run(hello))
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:977, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     974 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     976 try:
# --> 977   result = self._run(None, fetches, feed_dict, options_ptr,
#     978                      run_metadata_ptr)
#     979   if run_metadata:
#     980     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:1205, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1202       feed_map[compat.as_bytes(subfeed_t.name)] = (subfeed_t, subfeed_val)
#    1204 # Create a fetch handler to take care of the structure of fetches.
# -> 1205 fetch_handler = _FetchHandler(
#    1206     self._graph, fetches, feed_dict_tensor, feed_handles=feed_handles)
#    1208 # Run request and get response.
#    1209 # We need to keep the returned movers alive for the following _do_run().
#    1210 # These movers are no longer needed when _do_run() completes, and
#    1211 # are deleted when `movers` goes out of scope when this _run() ends.
#    1212 # TODO(yuanbyu, keveman): Revisit whether we should just treat feeding
#    1213 # of a handle from a different device as an error.
#    1214 _ = self._update_with_movers(feed_dict_tensor, feed_map)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:494, in _FetchHandler.__init__(self, graph, fetches, feeds, feed_handles)
#     482 """Creates a fetch handler.
#     483
#     484 Args:
#    (...)
#     491     direct feeds.
#     492 """
#     493 with graph.as_default():
# --> 494   self._fetch_mapper = _FetchMapper.for_fetch(fetches)
#     495 self._fetches = []
#     496 self._targets = []
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:285, in _FetchMapper.for_fetch(fetch)
#     283     if isinstance(fetch, tensor_type):
#     284       fetches, contraction_fn = fetch_fn(fetch)
# --> 285       return _ElementFetchMapper(fetches, contraction_fn)
#     286 # Did not find anything.
#     287 raise TypeError(f'Argument `fetch` = {fetch} has invalid type '
#     288                 f'"{type(fetch).__name__}"')
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:313, in _ElementFetchMapper.__init__(self, fetches, contraction_fn)
#     311 for fetch in fetches:
#     312   try:
# --> 313     self._unique_fetches.append(ops.get_default_graph().as_graph_element(
#     314         fetch, allow_tensor=True, allow_operation=True))
#     315   except TypeError as e:
#     316     raise TypeError(f'Argument `fetch` = {fetch} has invalid type '
#     317                     f'"{type(fetch).__name__}" must be a string or Tensor. '
#     318                     f'({str(e)})')
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:2929, in Graph.as_graph_element(self, obj, allow_tensor, allow_operation)
#    2926   return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#    2928 with self._lock:
# -> 2929   return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:3017, in Graph._as_graph_element_locked(self, obj, allow_tensor, allow_operation)
#    3013     raise ValueError(err_msg)
#    3015 elif isinstance(obj, tensor_lib.Tensor) and allow_tensor:
#    3016   # Actually obj is just the object it's referring to.
# -> 3017   if obj.graph is not self:
#    3018     raise ValueError("Tensor %s is not an element of this graph." % obj)
#    3019   return obj
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\tensor.py:260, in Tensor.__getattr__(self, name)
#     252 if name in {"T", "astype", "ravel", "transpose", "reshape", "clip", "size",
#     253             "tolist", "data"}:
#     254   # TODO(wangpeng): Export the enable_numpy_behavior knob
#     255   raise AttributeError(
#     256       f"{type(self).__name__} object has no attribute '{name}'. " + """
#     257     If you are looking for numpy-related methods, please run the following:
#     258     tf.experimental.numpy.experimental_enable_numpy_behavior()
#     259   """)
# --> 260 self.__getattribute__(name)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:606, in _EagerTensorBase.graph(self)
#     604 @property
#     605 def graph(self) -> NoReturn:
# --> 606   raise AttributeError(
#     607       "Tensor.graph is undefined when eager execution is enabled.")
#
# AttributeError: Tensor.graph is undefined when eager execution is enabled.

# %%
sess.run(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 sess.run(x)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:977, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     974 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     976 try:
# --> 977   result = self._run(None, fetches, feed_dict, options_ptr,
#     978                      run_metadata_ptr)
#     979   if run_metadata:
#     980     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:1205, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1202       feed_map[compat.as_bytes(subfeed_t.name)] = (subfeed_t, subfeed_val)
#    1204 # Create a fetch handler to take care of the structure of fetches.
# -> 1205 fetch_handler = _FetchHandler(
#    1206     self._graph, fetches, feed_dict_tensor, feed_handles=feed_handles)
#    1208 # Run request and get response.
#    1209 # We need to keep the returned movers alive for the following _do_run().
#    1210 # These movers are no longer needed when _do_run() completes, and
#    1211 # are deleted when `movers` goes out of scope when this _run() ends.
#    1212 # TODO(yuanbyu, keveman): Revisit whether we should just treat feeding
#    1213 # of a handle from a different device as an error.
#    1214 _ = self._update_with_movers(feed_dict_tensor, feed_map)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:494, in _FetchHandler.__init__(self, graph, fetches, feeds, feed_handles)
#     482 """Creates a fetch handler.
#     483
#     484 Args:
#    (...)
#     491     direct feeds.
#     492 """
#     493 with graph.as_default():
# --> 494   self._fetch_mapper = _FetchMapper.for_fetch(fetches)
#     495 self._fetches = []
#     496 self._targets = []
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:285, in _FetchMapper.for_fetch(fetch)
#     283     if isinstance(fetch, tensor_type):
#     284       fetches, contraction_fn = fetch_fn(fetch)
# --> 285       return _ElementFetchMapper(fetches, contraction_fn)
#     286 # Did not find anything.
#     287 raise TypeError(f'Argument `fetch` = {fetch} has invalid type '
#     288                 f'"{type(fetch).__name__}"')
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:313, in _ElementFetchMapper.__init__(self, fetches, contraction_fn)
#     311 for fetch in fetches:
#     312   try:
# --> 313     self._unique_fetches.append(ops.get_default_graph().as_graph_element(
#     314         fetch, allow_tensor=True, allow_operation=True))
#     315   except TypeError as e:
#     316     raise TypeError(f'Argument `fetch` = {fetch} has invalid type '
#     317                     f'"{type(fetch).__name__}" must be a string or Tensor. '
#     318                     f'({str(e)})')
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:2929, in Graph.as_graph_element(self, obj, allow_tensor, allow_operation)
#    2926   return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#    2928 with self._lock:
# -> 2929   return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:3017, in Graph._as_graph_element_locked(self, obj, allow_tensor, allow_operation)
#    3013     raise ValueError(err_msg)
#    3015 elif isinstance(obj, tensor_lib.Tensor) and allow_tensor:
#    3016   # Actually obj is just the object it's referring to.
# -> 3017   if obj.graph is not self:
#    3018     raise ValueError("Tensor %s is not an element of this graph." % obj)
#    3019   return obj
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\tensor.py:260, in Tensor.__getattr__(self, name)
#     252 if name in {"T", "astype", "ravel", "transpose", "reshape", "clip", "size",
#     253             "tolist", "data"}:
#     254   # TODO(wangpeng): Export the enable_numpy_behavior knob
#     255   raise AttributeError(
#     256       f"{type(self).__name__} object has no attribute '{name}'. " + """
#     257     If you are looking for numpy-related methods, please run the following:
#     258     tf.experimental.numpy.experimental_enable_numpy_behavior()
#     259   """)
# --> 260 self.__getattribute__(name)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:606, in _EagerTensorBase.graph(self)
#     604 @property
#     605 def graph(self) -> NoReturn:
# --> 606   raise AttributeError(
#     607       "Tensor.graph is undefined when eager execution is enabled.")
#
# AttributeError: Tensor.graph is undefined when eager execution is enabled.

# %%
type(sess.run(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 type(sess.run(x))
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:977, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     974 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     976 try:
# --> 977   result = self._run(None, fetches, feed_dict, options_ptr,
#     978                      run_metadata_ptr)
#     979   if run_metadata:
#     980     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:1205, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1202       feed_map[compat.as_bytes(subfeed_t.name)] = (subfeed_t, subfeed_val)
#    1204 # Create a fetch handler to take care of the structure of fetches.
# -> 1205 fetch_handler = _FetchHandler(
#    1206     self._graph, fetches, feed_dict_tensor, feed_handles=feed_handles)
#    1208 # Run request and get response.
#    1209 # We need to keep the returned movers alive for the following _do_run().
#    1210 # These movers are no longer needed when _do_run() completes, and
#    1211 # are deleted when `movers` goes out of scope when this _run() ends.
#    1212 # TODO(yuanbyu, keveman): Revisit whether we should just treat feeding
#    1213 # of a handle from a different device as an error.
#    1214 _ = self._update_with_movers(feed_dict_tensor, feed_map)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:494, in _FetchHandler.__init__(self, graph, fetches, feeds, feed_handles)
#     482 """Creates a fetch handler.
#     483
#     484 Args:
#    (...)
#     491     direct feeds.
#     492 """
#     493 with graph.as_default():
# --> 494   self._fetch_mapper = _FetchMapper.for_fetch(fetches)
#     495 self._fetches = []
#     496 self._targets = []
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:285, in _FetchMapper.for_fetch(fetch)
#     283     if isinstance(fetch, tensor_type):
#     284       fetches, contraction_fn = fetch_fn(fetch)
# --> 285       return _ElementFetchMapper(fetches, contraction_fn)
#     286 # Did not find anything.
#     287 raise TypeError(f'Argument `fetch` = {fetch} has invalid type '
#     288                 f'"{type(fetch).__name__}"')
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\client\session.py:313, in _ElementFetchMapper.__init__(self, fetches, contraction_fn)
#     311 for fetch in fetches:
#     312   try:
# --> 313     self._unique_fetches.append(ops.get_default_graph().as_graph_element(
#     314         fetch, allow_tensor=True, allow_operation=True))
#     315   except TypeError as e:
#     316     raise TypeError(f'Argument `fetch` = {fetch} has invalid type '
#     317                     f'"{type(fetch).__name__}" must be a string or Tensor. '
#     318                     f'({str(e)})')
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:2929, in Graph.as_graph_element(self, obj, allow_tensor, allow_operation)
#    2926   return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#    2928 with self._lock:
# -> 2929   return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:3017, in Graph._as_graph_element_locked(self, obj, allow_tensor, allow_operation)
#    3013     raise ValueError(err_msg)
#    3015 elif isinstance(obj, tensor_lib.Tensor) and allow_tensor:
#    3016   # Actually obj is just the object it's referring to.
# -> 3017   if obj.graph is not self:
#    3018     raise ValueError("Tensor %s is not an element of this graph." % obj)
#    3019   return obj
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\tensor.py:260, in Tensor.__getattr__(self, name)
#     252 if name in {"T", "astype", "ravel", "transpose", "reshape", "clip", "size",
#     253             "tolist", "data"}:
#     254   # TODO(wangpeng): Export the enable_numpy_behavior knob
#     255   raise AttributeError(
#     256       f"{type(self).__name__} object has no attribute '{name}'. " + """
#     257     If you are looking for numpy-related methods, please run the following:
#     258     tf.experimental.numpy.experimental_enable_numpy_behavior()
#     259   """)
# --> 260 self.__getattribute__(name)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:606, in _EagerTensorBase.graph(self)
#     604 @property
#     605 def graph(self) -> NoReturn:
# --> 606   raise AttributeError(
#     607       "Tensor.graph is undefined when eager execution is enabled.")
#
# AttributeError: Tensor.graph is undefined when eager execution is enabled.

# %% [markdown]
# ## Operations
#
# You can line up multiple Tensorflow operations in to be run during a session:

# %%
x = tf.constant(2)
y = tf.constant(3)

# %%
with tf.Session() as sess:
    print('Operations with Constants')
    print('Addition',sess.run(x+y))
    print('Subtraction',sess.run(x-y))
    print('Multiplication',sess.run(x*y))
    print('Division',sess.run(x/y))
# Out:
# Operations with Constants
# Addition 5
# Subtraction -1
# Multiplication 6
# Division 0.6666666666666666

# %% [markdown]
# ### Placeholder
#
# You may not always have the constants right away, and you may be waiting for a constant to appear after a cycle of operations. **tf.placeholder** is a tool for this. It inserts a placeholder for a tensor that will be always fed.
#
# **Important**: This tensor will produce an error if evaluated. Its value must be fed using the `feed_dict` optional argument to `Session.run()`,
# `Tensor.eval()`, or `Operation.run()`. For example, for a placeholder of a matrix of floating point numbers:
#
#     x = tf.placeholder(tf.float32, shape=(1024, 1024))
#
# Here is an example for integer placeholders:

# %%
x = tf.placeholder(tf.int32)
y = tf.placeholder(tf.int32)

# %%
x
# Out:
# <tf.Tensor 'Placeholder:0' shape=<unknown> dtype=int32>

# %%
type(x)
# Out:
# tensorflow.python.framework.ops.SymbolicTensor

# %% [markdown]
# ### Defining Operations

# %%
add = tf.add(x,y)
sub = tf.subtract(x,y)
mul = tf.multiply(x,y)

# %% [markdown]
# Running operations with variable input:

# %%
d = {x:20,y:30}

# %%
with tf.Session() as sess:
    print('Operations with Constants')
    print('Addition',sess.run(add,feed_dict=d))
    print('Subtraction',sess.run(sub,feed_dict=d))
    print('Multiplication',sess.run(mul,feed_dict=d))
# Out:
# Operations with Constants
# Addition 50
# Subtraction -10
# Multiplication 600

# %% [markdown]
# Now let's see an example of a more complex operation, using Matrix Multiplication. First we need to create the matrices:

# %%
import numpy as np
# Make sure to use floats here, int64 will cause an error.
a = np.array([[5.0,5.0]])
b = np.array([[2.0],[2.0]])

# %%
a
# Out:
# array([[5., 5.]])

# %%
a.shape
# Out:
# (1, 2)

# %%
b
# Out:
# array([[2.],
#        [2.]])

# %%
b.shape
# Out:
# (2, 1)

# %%
mat1 = tf.constant(a)

# %%
mat2 = tf.constant(b)

# %% [markdown]
# The matrix multiplication operation:

# %%
matrix_multi = tf.matmul(mat1,mat2)

# %% [markdown]
# Now run the session to perform the Operation:

# %%
with tf.Session() as sess:
    result = sess.run(matrix_multi)
    print(result)
# Out:
# [[20.]]

# %% [markdown]
# That is all for now! Next we will expand these basic concepts to construct out own Multi-Layer Perceptron model!

# %% [markdown]
# # Great Job!
